# %%
# Segmentation Library
# !pip install -U segmentation-models-pytorch

# Import
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import transforms
import csv
from sklearn.model_selection import train_test_split

# Model
import segmentation_models_pytorch as smp

# Preprocessing
from segmentation_models_pytorch.encoders import get_preprocessing_fn

# Metrics
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, jaccard_score
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.3.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.18.0+cu121)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting efficientnet-pytorch==0.7.1 (from segmentation-models-pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting timm==0.9.2 (from segmentation-models-pytorch)
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 81.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (4.66.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (9.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.3.0+cu121)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch)
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->segmentation-models-pytorch) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->segmentation-models-pytorch) (0.23.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->segmentation-models-pytorch) (0.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (4.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 76.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16429 sha256=9ab62aa610452c9f45c15a299304530268ad68ea5f6957302a6dfa6976901b5f
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60945 sha256=0c379f8b3b44d6e54a7061ab62152c41cd96ea32e9557f8e66b178771fd2cd99
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, munch, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, efficientnet-pytorch, timm, pretrainedmodels, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 munch-4.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.3.3 timm-0.9.2

# %%
# Dataset Download
# !wget -nc --no-check-certificate \
    "https://mm.cs.uec.ac.jp/uecfoodpix/UECFOODPIXCOMPLETE.tar" \
    -O "/content/dataset.tar"


# !tar -xvf /content/dataset.tar
# Out:
# Streaming output truncated to the last 5000 lines.
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/509.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/539.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/598.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/637.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/744.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/775.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/869.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/913.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1001.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1031.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1061.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11066.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14421.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10761.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1225.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1333.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1363.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1417.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1447.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1477.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14099.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1553.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11083.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14753.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1614.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1644.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15453.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1708.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14478.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1863.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1976.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2089.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2138.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2168.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10803.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11306.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14893.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16158.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2211.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2241.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2271.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9142.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11046.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2333.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2407.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2437.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2564.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2695.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2785.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2877.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2914.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2974.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2998.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3058.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3088.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3135.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3165.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3223.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3343.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3373.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3398.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3458.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10949.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12421.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15038.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15423.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15888.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3496.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3526.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3586.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3594.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3624.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3654.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3766.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3878.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3934.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4014.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4044.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4118.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4148.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4226.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4256.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4384.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4440.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4470.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4527.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4557.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4587.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4648.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4694.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4724.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4754.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4784.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4836.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4896.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5052.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5138.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5174.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5295.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5355.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5386.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5439.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11527.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5510.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5542.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5572.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5656.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10835.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5913.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5973.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5995.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6055.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6139.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6223.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6253.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6283.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6337.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6367.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6418.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6448.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6479.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6500.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9192.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6639.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6669.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6749.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6806.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6836.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6867.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6898.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7137.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7299.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7335.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7426.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7476.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7506.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7588.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7618.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16740.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7662.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7750.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7780.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7810.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7891.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7950.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8051.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8111.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15785.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8296.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8326.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8430.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8446.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8536.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8560.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8620.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11632.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8662.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8692.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8722.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8801.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8952.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8982.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9012.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11736.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11873.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14915.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11972.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12067.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12107.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12142.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12294.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12354.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12442.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13344.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13375.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13889.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12779.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13537.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12935.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14566.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12611.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14084.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11059.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11568.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12108.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13646.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13757.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13947.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14074.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14577.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14906.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15300.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15524.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15797.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16093.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4294.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/68.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/89.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/120.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/164.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/238.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/305.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/335.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/365.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/396.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14858.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/435.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11582.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12928.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14554.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15777.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/510.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14571.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/638.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/698.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/715.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11000.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/870.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9053.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13791.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/942.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/972.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1032.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1062.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1092.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1136.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1194.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13016.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1226.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1256.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1286.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1304.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1364.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1392.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1448.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1478.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11075.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14307.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1584.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14757.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15463.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1645.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1671.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9143.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15554.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13707.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1804.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1864.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9325.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1947.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1977.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14594.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2109.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2139.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11307.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14079.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14904.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2272.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2408.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2438.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11452.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2505.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2565.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14598.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2635.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2666.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2696.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15811.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2818.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2848.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11173.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2999.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3029.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3059.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3136.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3194.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3224.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3254.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3344.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3429.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3459.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10956.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15112.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15428.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3497.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3527.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3587.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3595.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3625.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3685.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3707.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14679.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3935.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3965.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4015.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4045.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4179.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4227.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4257.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4355.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4441.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4471.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4558.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4588.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4679.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4725.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4785.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4867.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4897.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/373.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5022.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5139.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5206.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5356.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5410.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5440.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5470.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11552.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5511.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5597.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5627.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5712.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5772.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5801.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5861.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16720.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6026.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6056.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6086.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6140.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6170.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6194.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6338.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6389.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6449.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6501.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6531.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6640.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6750.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6780.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6837.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6899.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7447.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7537.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7559.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7589.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16741.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7751.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7781.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16726.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7892.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7981.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8082.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8112.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8163.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8193.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8327.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8341.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8537.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8561.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8772.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8802.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8840.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8900.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8930.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8953.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9013.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11706.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11738.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11876.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11913.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11943.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11973.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12040.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12068.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12173.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12240.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12265.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12373.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12407.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12443.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15742.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13345.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13965.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12694.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12724.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12754.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12780.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12810.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12840.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14865.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13507.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13538.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13715.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12966.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12580.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13118.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13148.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13179.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11573.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13948.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15301.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16124.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/121.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/165.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/195.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/239.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/366.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/496.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11617.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14567.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/541.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/570.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14572.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/609.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/639.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/669.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/699.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/716.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11044.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/871.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14264.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/973.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1033.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1093.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11069.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1137.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14424.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14718.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10922.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11156.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11650.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13787.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13992.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14368.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15041.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15885.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16290.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5158.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/71.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9104.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15280.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10770.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/218.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/278.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13772.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/315.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/376.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15442.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/475.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13756.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15124.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15957.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/520.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/550.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/579.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9360.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15049.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9226.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/725.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/756.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/786.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11348.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15847.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/820.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/850.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/880.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9314.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/982.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1012.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1042.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1072.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1145.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13027.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6918.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1206.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1236.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1314.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1373.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1428.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1488.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1504.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15349.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1564.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9039.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11561.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15021.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15606.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1653.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1681.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9330.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1719.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14674.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1814.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1844.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1897.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1957.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1987.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2040.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15867.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2119.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2179.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11697.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2222.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13607.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2314.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2344.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2418.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2448.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2515.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2545.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2615.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2646.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2677.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11679.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2828.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2858.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2925.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3009.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3069.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13319.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3146.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3176.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3204.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3264.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3294.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3324.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3384.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3409.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3469.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10631.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11137.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12556.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14583.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3507.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3605.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3635.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3665.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3747.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3859.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3975.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3994.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4055.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4334.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4365.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4451.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4481.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4507.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4538.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4596.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4629.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4689.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4705.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4765.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4817.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4847.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4877.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4960.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5032.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5063.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5249.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5306.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5390.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5480.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5523.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5553.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5583.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5607.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5667.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5782.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5811.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5841.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5924.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6036.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6066.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6150.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6204.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9356.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6348.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6378.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6429.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6459.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6620.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6650.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6680.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6700.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6760.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9238.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6817.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6879.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6930.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7183.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7347.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7407.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7437.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7487.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7569.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7599.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7643.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7673.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7703.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7733.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7761.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7791.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7842.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14795.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8062.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8173.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8233.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8307.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8337.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8351.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9281.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8457.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8487.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8571.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8631.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8733.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14803.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8812.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11142.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8880.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11780.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12050.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12080.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12153.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12305.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12335.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12365.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12418.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12454.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13317.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13355.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12674.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12704.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12764.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12820.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12850.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16131.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12946.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12976.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12558.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12658.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13158.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13190.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11159.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11686.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13236.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13708.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13806.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14615.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14818.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15583.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7145.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9106.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/153.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10772.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/219.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/249.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/279.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/346.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11233.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/446.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15129.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/521.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5502.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10577.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/649.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9231.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9337.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15773.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/925.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/953.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/983.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1013.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1073.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1174.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13028.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6934.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1267.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1297.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1315.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1459.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13580.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1505.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1535.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1565.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9063.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11687.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15045.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15624.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1626.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1654.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9331.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1720.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1750.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14688.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1845.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1875.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1928.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1958.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1988.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2011.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2041.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10695.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15899.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2150.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11492.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15069.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15740.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2193.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2223.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2253.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2283.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2375.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2419.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15767.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2546.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2647.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2707.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2767.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2829.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2859.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2956.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2986.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3010.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3040.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13692.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3117.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3177.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3205.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3265.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3325.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3470.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10637.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11158.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12566.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14630.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15303.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16170.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3538.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3568.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9298.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3636.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14378.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3718.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3778.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3799.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3830.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3890.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3916.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3946.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3976.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3995.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4026.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4056.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4086.png
# ...
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13178.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14329.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14759.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16701.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5077.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/100.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/147.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/194.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/208.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/268.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/299.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/405.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/465.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/495.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/540.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/569.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/599.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/608.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/668.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/745.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/776.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14725.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/810.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/840.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/914.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1002.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11067.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1163.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14423.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14700.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10920.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1334.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1418.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1525.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1554.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11089.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15958.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1615.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1709.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1739.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1769.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14479.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1834.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15952.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1917.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2000.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2030.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2060.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2090.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2169.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9155.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/10810.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11648.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15544.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16268.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2212.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2242.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9144.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11047.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2304.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2334.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2364.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9257.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2469.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2535.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9207.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2603.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9350.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2726.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2756.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2786.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2878.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2915.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2945.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/2975.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3089.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3106.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3166.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3284.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3314.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3374.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3399.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3490.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12422.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14062.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15893.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3557.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9114.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3655.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3737.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3767.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3818.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3849.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3879.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/3905.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16725.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4075.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15356.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4119.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4149.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4197.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4289.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4322.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4385.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4411.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4497.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4528.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4619.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4649.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4695.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4755.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4807.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4837.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4927.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5053.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5088.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5105.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5175.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5238.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5269.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5296.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5326.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5387.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5543.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5573.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5657.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5687.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5742.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5831.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5914.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5944.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5974.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5996.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6110.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6224.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6254.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6284.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6308.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6368.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6419.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6480.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6561.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9228.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6610.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6670.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6690.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6720.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6807.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/6868.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7140.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7301.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7336.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7367.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7397.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7427.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7477.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7507.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7619.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7663.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7693.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7723.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7811.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7862.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7922.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7951.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8011.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11203.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8052.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15577.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8223.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16313.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8267.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8297.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8371.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8401.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8431.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8447.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8477.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8507.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8591.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8621.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11635.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8663.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8693.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8723.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11696.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8742.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8832.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8870.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/8983.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11769.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11801.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14990.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12008.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12109.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12143.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12210.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12295.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12325.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12355.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13307.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13376.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12528.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12664.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12936.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15138.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12612.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12645.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/11063.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12169.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13671.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13763.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14076.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14341.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14584.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14787.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14909.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15534.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15803.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/16706.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/4300.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/5087.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/69.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/101.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/148.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/209.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/269.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9236.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/306.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/336.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/397.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14859.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/406.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/436.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/466.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/12929.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/15815.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/511.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/7098.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/746.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/777.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/14861.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/811.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/841.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/9054.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/915.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/943.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1003.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1063.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1164.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/1195.png
# UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask/13017.png
# UECFOODPIXCOMPLETE/data/train9000.txt

# %%
# Dataset class
class CustomDatasetUEC(Dataset):
    def __init__(self, image_names_file, image_dir, mask_dir, transform=None):
        self.image_names_file = image_names_file
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.image_names = []
        self.image_paths = {}  # Dictionary that stores images path
        self.masks = []
        self.load_data()

        # Pre-processing
        self.preprocess_input = smp.encoders.get_preprocessing_fn('resnet34', pretrained='imagenet')

        # Define a transformation for the preprocessing function
        self.transform = transforms.Compose([
            transforms.Resize((512, 512)),
            transforms.ToTensor()
        ])

    def load_data(self):
        with open(self.image_names_file) as f:
            for line in f:
                image_name = line.strip()
                self.image_names.append(image_name)

    def load_image(self, image_path):
        image = Image.open(image_path)
        return image

    def load_mask(self, mask_path):
        mask = Image.open(mask_path).convert("RGB")
        red_channel = mask.split()[0]  # Estract red channel
        binary_mask = np.where(np.array(red_channel) > 0, 1, 0)  # Convert to binary
        binary_mask_image = Image.fromarray((binary_mask * 255).astype(np.uint8), mode="L")  # Convert to binary
        return binary_mask_image

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, index):
        image_name = self.image_names[index]

        if image_name not in self.image_paths:
            image_path = os.path.join(self.image_dir, image_name + ".jpg")
            self.image_paths[image_name] = image_path

        image = self.load_image(self.image_paths[image_name])
        mask_path = os.path.join(self.mask_dir, image_name + ".png")
        mask = self.load_mask(mask_path)

        if self.transform:
            image = self.transform(image)
            image = image.numpy().transpose((1, 2, 0))  # Convert to numpy and transpose to HWC
            image = self.preprocess_input(image)  # Apply preprocessing function
            image = torch.tensor(image).permute(2, 0, 1).float()  # Convert back to tensor and transpose to CHW
            mask = self.transform(mask)

        return image, mask

# Set dir train set
image_names_file = "/content/UECFOODPIXCOMPLETE/data/train9000.txt"
image_dir = "/content/UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/img"
mask_dir = "/content/UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/train/mask"

# Set dir for test set
test_image_names_file = "/content/UECFOODPIXCOMPLETE/data/test1000.txt"
test_image_dir = "/content/UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/test/img"
test_mask_dir = "/content/UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/test/mask"

# Create val set from split test set
# Set dir for val set
val_image_dir = "/content/UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/val/img"
val_mask_dir = "/content/UECFOODPIXCOMPLETE/data/UECFoodPIXCOMPLETE/val/mask"
os.makedirs(val_image_dir, exist_ok=True)
os.makedirs(val_mask_dir, exist_ok=True)

# Read image names from file
with open(image_names_file) as f:
    image_names = [line.strip() for line in f]

# Perform split 80 - 20
image_names_file_s, val_image_names_file_s = train_test_split(image_names, test_size=0.2, shuffle=False)

# Move images and masks to val folder
for name in val_image_names_file_s:
    val_image_path = os.path.join(image_dir, name + '.jpg')
    val_mask_path = os.path.join(mask_dir, name + '.png')

    if not os.path.exists(os.path.join(val_image_dir, name + '.jpg')):
        shutil.move(val_image_path, val_image_dir)

    if not os.path.exists(os.path.join(val_mask_dir, name + '.png')):
        shutil.move(val_mask_path, val_mask_dir)

# Create new 800 images/masks train set
with open('/content/UECFOODPIXCOMPLETE/data/train7200.txt', 'w') as f:
    for line in image_names_file_s:
        f.write(line.strip() + '\n')
image_names_file_7200 = "/content/UECFOODPIXCOMPLETE/data/train7200.txt"

# Create new 200 images/masks val set
with open('/content/UECFOODPIXCOMPLETE/data/val1800.txt', 'w') as f:
    for line in val_image_names_file_s:
        f.write(line.strip() + '\n')
val_image_names_file_1800 = "/content/UECFOODPIXCOMPLETE/data/val1800.txt"

# Create train dataset/dataloader
dataset = CustomDatasetUEC(image_names_file_7200, image_dir, mask_dir)
data_loader = torch.utils.data.DataLoader(dataset, batch_size=8, shuffle=True)

# Create test dataset/dataloader
test_dataset = CustomDatasetUEC(test_image_names_file, test_image_dir, test_mask_dir)
test_data_loader = torch.utils.data.DataLoader(test_dataset, batch_size=8, shuffle=False)

# Create val dataset/dataloader
val_dataset = CustomDatasetUEC(val_image_names_file_1800, val_image_dir, val_mask_dir)
val_data_loader = torch.utils.data.DataLoader(val_dataset, batch_size=8, shuffle=False)

# Access the data
image, mask = dataset[1]
test_image, test_mask = test_dataset[1]
val_image, val_mask = val_dataset[2]

# Visualize train image and mask
fig, ax = plt.subplots(1, 2)
ax[0].imshow(image.permute(1, 2, 0).numpy())
ax[0].set_title("Image [Train]")
ax[1].imshow(mask.squeeze(), cmap='gray')
ax[1].set_title("Mask [Train]")
plt.show()

# Visualize test image and mask
fig, ax = plt.subplots(1, 2)
ax[0].imshow(test_image.permute(1, 2, 0).numpy())
ax[0].set_title("Image [Test]")
ax[1].imshow(test_mask.squeeze(), cmap='gray')
ax[1].set_title("Mask [Test]")
plt.show()

# Visualize val image and mask
fig, ax = plt.subplots(1, 2)
ax[0].imshow(val_image.permute(1, 2, 0).numpy())
ax[0].set_title("Image [Val]")
ax[1].imshow(val_mask.squeeze(), cmap='gray')
ax[1].set_title("Mask [Val]")
plt.show()

def plot_images_and_masks(dataset, indices, title_prefix):
    for idx in indices:
        image, mask = dataset[idx]

        fig, ax = plt.subplots(1, 2)
        ax[0].imshow(image.permute(1, 2, 0).numpy())
        ax[0].set_title(f"{title_prefix} Image [{idx}]")
        ax[1].imshow(mask.squeeze(), cmap='gray')
        ax[1].set_title(f"{title_prefix} Mask [{idx}]")
        plt.show()

# Visualizza un batch di immagini e maschere dal training set
plot_images_and_masks(dataset, range(0, 20), "Train")

# Visualizza un batch di immagini e maschere dal test set
plot_images_and_masks(test_dataset, range(0, 20), "Test")

# Visualizza un batch di immagini e maschere dal validation set
plot_images_and_masks(val_dataset, range(0, 20), "Val")

# %%
# Model Definition
model = smp.PSPNet(
    encoder_name="resnet34",
    encoder_weights="imagenet",
    in_channels=3,
    classes=1,
    encoder_depth=3,
    psp_out_channels=1,
    psp_use_batchnorm=True,
    psp_dropout=0.2,
    activation='sigmoid',
    upsampling=8,
    aux_params=None,
)

# Define loss function, and optimizer
loss = smp.losses.DiceLoss(mode="binary")

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 369MB/s]

# %%
# TRAIN
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
loss.to(device)

# Early Stopping
best_metric = 0.0
no_improvement_epochs = 0
patience = 3  # Maximum number of epochs without improvement to be tolerated
val_metrics = []

# Calculate Losses, Jaccard and F1
train_losses = []
val_losses = []
train_jaccard = []
val_jaccard = []
val_f1_scores = []

# Epochs
num_epochs = 15
epoch_loss = 0

for epoch in range(num_epochs):
    print(f"Epoch {epoch+1}/{num_epochs}")
    print("-" * 10)

    model.train()  # Set model to training mode

    for batch_idx, (images, masks) in enumerate(data_loader):

        # To GPU
        images = images.to(device)
        masks = masks.to(device)

        # Optimizer
        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)

        # Convert masks to index tensor
        masks = masks.round().long()

        # Calculate loss
        loss_value = loss(outputs, masks)

        # Accumulate loss
        epoch_loss += loss_value.item()

        # Compute predicted labels
        predicted_labels = torch.argmax(outputs, dim=1)

        # Treshold predicted
        predicted_labels = torch.where(outputs > 0.5, torch.tensor(1), torch.tensor(0))

        # Backward pass and optimization
        loss_value.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print(f"Batch {batch_idx}/{len(data_loader)} - Loss: {loss_value.item()}")

    # Compute metrics after each epoch
    y_pred = predicted_labels.cpu().flatten()
    y_true = masks.cpu().flatten()

    accuracy = accuracy_score(y_true, y_pred)
    confusion = confusion_matrix(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    jaccard = jaccard_score(y_true, y_pred)
    train_jaccard.append(jaccard)

    accuracy = round(accuracy, 3)
    precision = round(precision, 3)
    recall = round(recall, 3)
    f1 = round(f1, 3)
    jaccard = round(jaccard, 3)

    # Print or store the metrics
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("Jaccard Score:", jaccard)
    print(" ")

    # Compute average loss
    epoch_loss /= len(data_loader)
    train_losses.append(epoch_loss)

    # Early stopping
    model.eval()

    with torch.no_grad():

        print(f"Validation Set")
        print("-" * 10)

        epoch_val_loss = 0

        for batch_idx, (val_image, val_mask) in enumerate(val_data_loader):

            # To GPU
            val_image = val_image.to(device)
            val_mask = val_mask.to(device)

            # Forward pass
            outputs = model(val_image)

            # Convert masks to index tensors
            val_mask = val_mask.round().long()

            # Calculate loss
            loss_value = loss(outputs, val_mask)

            # Save validation loss
            epoch_val_loss += loss_value.item()

            # Calculate the predicted labels
            predicted_labels = torch.argmax(outputs, dim=1)

            # Treshold predicted
            predicted_labels = torch.where(outputs > 0.5, torch.tensor(1), torch.tensor(0))

            if batch_idx % 100 == 0:
              print(f"Batch {batch_idx}/{len(val_data_loader)} - Loss: {loss_value.item()}")

        # Compute metrics after each epoch
        y_pred = predicted_labels.cpu().flatten()
        y_true = val_mask.cpu().flatten()

        # Compute average loss
        epoch_val_loss /= len(val_data_loader)
        val_losses.append(epoch_val_loss)

        # Compute Jaccard score
        val_jacc = jaccard_score(y_true, y_pred)
        val_jaccard.append(val_jacc)

        # Compute F1 score
        f1 = f1_score(y_true, y_pred)
        val_f1_scores.append(f1)

        # Set early stopping metric
        current_metric = val_f1_scores[-1]
        print("F1 Score:", current_metric)
        print("Jaccard Score:", val_jacc)
        print(" ")

        # Check for improvement
        if current_metric > best_metric:
            best_metric = current_metric
            no_improvement_epochs = 0
        else:
            no_improvement_epochs += 1

        # Check if number of epochs without improvement reached the patience threshold
        if no_improvement_epochs >= patience:
            print(f"Early stopping: F1 score has not improved for {patience} epochs")
            print(f"Best F1 score: {best_metric}")
            print(f" ")
            break


# Plot Loss
train_epochs = [i+1 for i in range(len(train_losses))]
val_epochs = [i+1 for i in range(len(val_losses))]

plt.plot(train_epochs, train_losses, label='Train Loss')
plt.plot(val_epochs, val_losses, label='Validation Loss')

# Find min and max of losses and trace overfit line
min_epoch = val_epochs[val_losses.index(min(val_losses))]
min_loss = min(min(train_losses), min(val_losses))
max_loss = max(max(train_losses), max(val_losses))
plt.vlines(min_epoch, min_loss, max_loss, linestyles='--', colors='red', label='Overfitting')
plt.title('Train and Val Losses')
plt.xlabel('Epochs')
plt.xticks(val_epochs)
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot validation F1 score
plt.plot(val_epochs, val_f1_scores, label='F1 Score')
plt.title('Validation F1 Score')
plt.xlabel('Epochs')
plt.xticks(val_epochs)
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# Plt Jaccard
train_epochs_jacc = [i+1 for i in range(len(train_jaccard))]
val_epochs_jacc = [i+1 for i in range(len(val_jaccard))]
plt.plot(train_epochs_jacc, train_jaccard, label='Train Jaccard')
plt.plot(val_epochs_jacc, val_jaccard, label='Validation Jaccard')
plt.title('Jaccard Score')
plt.xlabel('Epochs')
plt.xticks(val_epochs_jacc)
plt.ylabel('Jaccard Score')
plt.legend()
plt.show()

print(" ")
best_epoch = train_jaccard.index(max(train_jaccard))
print(f'Best Train Epoch: {best_epoch+1}')

print(" ")
if min_epoch == len(val_losses):
    print(f'')
else:
    print(f'Validation Overfit in Epoch: {min_epoch} with value: {val_losses[min_epoch]}')
# Out:
# Epoch 1/15
# ----------
# Batch 0/900 - Loss: 0.4952569603919983
# Batch 100/900 - Loss: 0.551230788230896
# Batch 200/900 - Loss: 0.5105993747711182
# Batch 300/900 - Loss: 0.4861246943473816
# Batch 400/900 - Loss: 0.5005050897598267
# Batch 500/900 - Loss: 0.4407306909561157
# Batch 600/900 - Loss: 0.4058515429496765
# Batch 700/900 - Loss: 0.4793596863746643
# Batch 800/900 - Loss: 0.3919254541397095
# Accuracy: 0.787
# Precision: 0.634
# Recall: 0.987
# F1 Score: 0.772
# Jaccard Score: 0.629
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.4779379963874817
# Batch 100/225 - Loss: 0.3471790552139282
# Batch 200/225 - Loss: 0.47430354356765747
# F1 Score: 0.8470762626104258
# Jaccard Score: 0.7347201164652557
#
# Epoch 2/15
# ----------
# Batch 0/900 - Loss: 0.4325408339500427
# Batch 100/900 - Loss: 0.37774938344955444
# Batch 200/900 - Loss: 0.4534016251564026
# Batch 300/900 - Loss: 0.46019768714904785
# Batch 400/900 - Loss: 0.47435885667800903
# Batch 500/900 - Loss: 0.40343254804611206
# Batch 600/900 - Loss: 0.5280039310455322
# Batch 700/900 - Loss: 0.4689975380897522
# Batch 800/900 - Loss: 0.45845866203308105
# Accuracy: 0.818
# Precision: 0.719
# Recall: 0.936
# F1 Score: 0.813
# Jaccard Score: 0.686
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.46414828300476074
# Batch 100/225 - Loss: 0.3246647119522095
# Batch 200/225 - Loss: 0.45462632179260254
# F1 Score: 0.8733747403438972
# Jaccard Score: 0.775213171246037
#
# Epoch 3/15
# ----------
# Batch 0/900 - Loss: 0.48014432191848755
# Batch 100/900 - Loss: 0.42129600048065186
# Batch 200/900 - Loss: 0.34541285037994385
# Batch 300/900 - Loss: 0.4822005033493042
# Batch 400/900 - Loss: 0.47949373722076416
# Batch 500/900 - Loss: 0.4492475986480713
# Batch 600/900 - Loss: 0.49357283115386963
# Batch 700/900 - Loss: 0.41397351026535034
# Batch 800/900 - Loss: 0.4954700469970703
# Accuracy: 0.813
# Precision: 0.723
# Recall: 0.961
# F1 Score: 0.825
# Jaccard Score: 0.702
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.45629775524139404
# Batch 100/225 - Loss: 0.31506431102752686
# Batch 200/225 - Loss: 0.447661817073822
# F1 Score: 0.8963379265908097
# Jaccard Score: 0.812148888855118
#
# Epoch 4/15
# ----------
# Batch 0/900 - Loss: 0.4507477879524231
# Batch 100/900 - Loss: 0.4053419828414917
# Batch 200/900 - Loss: 0.3682953715324402
# Batch 300/900 - Loss: 0.3628852367401123
# Batch 400/900 - Loss: 0.4206685423851013
# Batch 500/900 - Loss: 0.43773114681243896
# Batch 600/900 - Loss: 0.38913339376449585
# Batch 700/900 - Loss: 0.3919219970703125
# Batch 800/900 - Loss: 0.3453162908554077
# Accuracy: 0.889
# Precision: 0.772
# Recall: 0.981
# F1 Score: 0.864
# Jaccard Score: 0.76
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.4455610513687134
# Batch 100/225 - Loss: 0.3090396523475647
# Batch 200/225 - Loss: 0.4437609910964966
# F1 Score: 0.8985000214028434
# Jaccard Score: 0.8157058909317011
#
# Epoch 5/15
# ----------
# Batch 0/900 - Loss: 0.452056348323822
# Batch 100/900 - Loss: 0.4240722060203552
# Batch 200/900 - Loss: 0.4712487459182739
# Batch 300/900 - Loss: 0.42023760080337524
# Batch 400/900 - Loss: 0.3924551010131836
# Batch 500/900 - Loss: 0.3756871819496155
# Batch 600/900 - Loss: 0.5007479190826416
# Batch 700/900 - Loss: 0.48636889457702637
# Batch 800/900 - Loss: 0.40799468755722046
# Accuracy: 0.932
# Precision: 0.908
# Recall: 0.93
# F1 Score: 0.919
# Jaccard Score: 0.85
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.4466020464897156
# Batch 100/225 - Loss: 0.304929256439209
# Batch 200/225 - Loss: 0.43851304054260254
# F1 Score: 0.9196618586536841
# Jaccard Score: 0.8512722299220157
#
# Epoch 6/15
# ----------
# Batch 0/900 - Loss: 0.38821911811828613
# Batch 100/900 - Loss: 0.4388348460197449
# Batch 200/900 - Loss: 0.3690398335456848
# Batch 300/900 - Loss: 0.5517669320106506
# Batch 400/900 - Loss: 0.4269738793373108
# Batch 500/900 - Loss: 0.42078298330307007
# Batch 600/900 - Loss: 0.41800808906555176
# Batch 700/900 - Loss: 0.41788798570632935
# Batch 800/900 - Loss: 0.4223388433456421
# Accuracy: 0.745
# Precision: 0.63
# Recall: 0.985
# F1 Score: 0.769
# Jaccard Score: 0.624
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.44379764795303345
# Batch 100/225 - Loss: 0.3027532696723938
# Batch 200/225 - Loss: 0.4387779235839844
# F1 Score: 0.8979600856453691
# Jaccard Score: 0.814816300162074
#
# Epoch 7/15
# ----------
# Batch 0/900 - Loss: 0.40815502405166626
# Batch 100/900 - Loss: 0.41144222021102905
# Batch 200/900 - Loss: 0.3578968048095703
# Batch 300/900 - Loss: 0.348114013671875
# Batch 400/900 - Loss: 0.3996490240097046
# Batch 500/900 - Loss: 0.42619019746780396
# Batch 600/900 - Loss: 0.40856796503067017
# Batch 700/900 - Loss: 0.4598386287689209
# Batch 800/900 - Loss: 0.365120530128479
# Accuracy: 0.829
# Precision: 0.741
# Recall: 0.954
# F1 Score: 0.834
# Jaccard Score: 0.716
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.44322192668914795
# Batch 100/225 - Loss: 0.30355769395828247
# Batch 200/225 - Loss: 0.4384017586708069
# F1 Score: 0.922718071676049
# Jaccard Score: 0.8565242277029801
#
# Epoch 8/15
# ----------
# Batch 0/900 - Loss: 0.4146192669868469
# Batch 100/900 - Loss: 0.4490070343017578
# Batch 200/900 - Loss: 0.38853561878204346
# Batch 300/900 - Loss: 0.36796027421951294
# Batch 400/900 - Loss: 0.442973256111145
# Batch 500/900 - Loss: 0.3879880905151367
# Batch 600/900 - Loss: 0.4251521825790405
# Batch 700/900 - Loss: 0.47578340768814087
# Batch 800/900 - Loss: 0.43438905477523804
# Accuracy: 0.764
# Precision: 0.591
# Recall: 0.996
# F1 Score: 0.742
# Jaccard Score: 0.59
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.44147151708602905
# Batch 100/225 - Loss: 0.3035883903503418
# Batch 200/225 - Loss: 0.4391239285469055
# F1 Score: 0.8760713138211627
# Jaccard Score: 0.7794723318252984
#
# Epoch 9/15
# ----------
# Batch 0/900 - Loss: 0.3846285343170166
# Batch 100/900 - Loss: 0.4142876863479614
# Batch 200/900 - Loss: 0.38520628213882446
# Batch 300/900 - Loss: 0.4129558801651001
# Batch 400/900 - Loss: 0.32400089502334595
# Batch 500/900 - Loss: 0.43738895654678345
# Batch 600/900 - Loss: 0.3629382848739624
# Batch 700/900 - Loss: 0.338423490524292
# Batch 800/900 - Loss: 0.41347652673721313
# Accuracy: 0.796
# Precision: 0.699
# Recall: 0.978
# F1 Score: 0.815
# Jaccard Score: 0.688
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.44270092248916626
# Batch 100/225 - Loss: 0.3029712438583374
# Batch 200/225 - Loss: 0.43715572357177734
# F1 Score: 0.9122996378845519
# Jaccard Score: 0.8387416881155003
#
# Epoch 10/15
# ----------
# Batch 0/900 - Loss: 0.460426390171051
# Batch 100/900 - Loss: 0.41542136669158936
# Batch 200/900 - Loss: 0.39983928203582764
# Batch 300/900 - Loss: 0.31242549419403076
# Batch 400/900 - Loss: 0.3843032717704773
# Batch 500/900 - Loss: 0.37016236782073975
# Batch 600/900 - Loss: 0.4286649823188782
# Batch 700/900 - Loss: 0.43417423963546753
# Batch 800/900 - Loss: 0.39952367544174194
# Accuracy: 0.846
# Precision: 0.718
# Recall: 0.964
# F1 Score: 0.823
# Jaccard Score: 0.7
#
# Validation Set
# ----------
# Batch 0/225 - Loss: 0.43792200088500977
# Batch 100/225 - Loss: 0.29867154359817505
# Batch 200/225 - Loss: 0.43555641174316406
# F1 Score: 0.9210025778018309
# Jaccard Score: 0.853572546934852
#
# Early stopping: F1 score has not improved for 3 epochs
# Best F1 score: 0.922718071676049
#
# Best Train Epoch: 5

# %%
from google.colab import files

#Save checkpoint
torch.save(model.state_dict(), '/content/checkpointN_15_PSPNet_resnet34.pt')

files.download('/content/checkpointN_15_PSPNet_resnet34.pt')

# %%
'''
# Download ad Load Last Checkpoint
# !wget --no-check-certificate \
    "https://www.dropbox.com/scl/fi/c8gb3v7cnc8xf2ec1pp73/checkpoint_15_DeepLabV3_resnet34.pt?rlkey=v19jv3dr442psas2sv7hg4z6m&st=fgpbb3bb&dl=1" \
    -O "/content/checkpoint_15_DeepLabV3_resnet34.pt"

model.load_state_dict(torch.load("/content/checkpoint_15_DeepLabV3_resnet34.pt"))

'''
# Out:
# '\n# Download ad Load Last Checkpoint\n!wget --no-check-certificate     "https://www.dropbox.com/scl/fi/c8gb3v7cnc8xf2ec1pp73/checkpoint_15_DeepLabV3_resnet34.pt?rlkey=v19jv3dr442psas2sv7hg4z6m&st=fgpbb3bb&dl=1"     -O "/content/checkpoint_15_DeepLabV3_resnet34.pt"\n\nmodel.load_state_dict(torch.load("/content/checkpoint_15_DeepLabV3_resnet34.pt"))\n\n'

# %%
# TEST
import sklearn.metrics as metrics

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
loss.to(device)

model.eval()

with torch.no_grad():
    for batch_idx, (test_image, test_mask) in enumerate(test_data_loader):

        # To GPU
        test_image = test_image.to(device)
        test_mask = test_mask.to(device)

        # Forward pass
        outputs = model(test_image)

        # Convert masks to index tensors
        test_mask = test_mask.round().long()

        loss_value = loss(outputs, test_mask)

        # Calculate the predicted labels
        predicted_labels = torch.argmax(outputs, dim=1)

        # Treshold predicted
        predicted_labels = torch.where(outputs > 0.5, torch.tensor(1), torch.tensor(0))

        # Some example images
        if batch_idx < 4:  # Only 2 batches
            for i in range(test_image.size(0)):
                image = test_image[i].cpu().numpy().transpose(1, 2, 0)  # Image to ndarray
                predicted_mask = predicted_labels[i].cpu().numpy()  # Predicted mask to ndarray
                original_mask = test_mask[i].cpu().numpy()  # Original mask to ndarray

                image = image / image.max()

                plt.figure()
                plt.subplot(1, 3, 1)
                plt.imshow(image)
                plt.title("Image")
                plt.axis('off')

                plt.subplot(1, 3, 2)
                plt.imshow(predicted_mask.squeeze(), cmap='gray')
                plt.title("Predicted mask")
                plt.axis('off')

                plt.subplot(1, 3, 3)
                plt.imshow(np.squeeze(original_mask), cmap='gray')
                plt.title("Original mask")
                plt.axis('off')

                plt.show()

    # Compute metrics after each epoch
    y_pred = predicted_labels.cpu().flatten()
    y_true = test_mask.cpu().flatten()

    accuracy = accuracy_score(y_true, y_pred)
    confusion = confusion_matrix(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    jaccard = jaccard_score(y_true, y_pred)

    accuracy = round(accuracy, 3)
    precision = round(precision, 3)
    recall = round(recall, 3)
    f1 = round(f1, 3)
    jaccard = round(jaccard, 3)

    # Print the metrics
    print("")
    print("--- METRICS ---")
    print("Accuracy:", accuracy)
    print("Confusion Matrix:")
    print(confusion)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("Jaccard Score:", jaccard)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
